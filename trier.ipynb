# %%
import os 
import pandas as pd

# %%
# getting currecnt working dirctory
cwd = os.getcwd()
path = cwd + '/TPData1'

stocklist = []
for filename in os.listdir(path):
    if filename.endswith('.csv'):
        stocklist.append(filename[3:-4])
print(f'There are {len(stocklist)} stocks in S&P500 \n')

length = {}
for stock in stocklist:
    datapath = path + f'/tp_{stock}' +'.csv'
    df = pd.read_csv(datapath)
    L = len(df)
    date = df.index
    length.update({f'{stock}':f'{L}'})

length
# Out:
# There are 494 stocks in S&P500
# {'ABMD': '502',
#  'AMD': '502',
#  'SPG': '502',
#  'AAP': '502',
#  'AVY': '502',
#  'NTAP': '502',
#  'MLM': '502',
#  'GRMN': '502',
#  'WU': '502',
#  'DLTR': '502',
#  'KMX': '502',
#  'TMUS': '502',
#  'WHR': '502',
#  'URI': '502',
#  'AAPL': '502',
#  'PNC': '502',
#  'LH': '502',
#  'RTX': '502',
#  'WEC': '502',
#  'CF': '502',
#  'UDR': '502',
#  'NWSA': '502',
#  'BIO': '502',
#  'TTWO': '502',
#  'HPQ': '502',
#  'PBCT': '502',
#  'MXIM': '502',
#  'CCL': '502',
#  'CMG': '502',
#  'SHW': '502',
#  'AWK': '502',
#  'COO': '502',
#  'FISV': '502',
#  'ACN': '502',
#  'AME': '502',
#  'AMP': '502',
#  'CVX': '502',
#  'XOM': '502',
#  'FRT': '502',
#  'CME': '502',
#  'FRC': '502',
#  'ZBH': '502',
#  'DFS': '502',
#  'HRL': '502',
#  'LRCX': '502',
#  'SEE': '502',
#  'UHS': '502',
#  'BKR': '502',
#  'BEN': '502',
#  'PNW': '502',
#  'ICE': '502',
#  'MO': '502',
#  'EXC': '502',
#  'BA': '502',
#  'CE': '502',
#  'ROP': '502',
#  'CAG': '502',
#  'HPE': '502',
#  'AXP': '502',
#  'AZO': '502',
#  'CTSH': '502',
#  'CMS': '502',
#  'FDX': '502',
#  'KEYS': '502',
#  'ZTS': '502',
#  'WYNN': '502',
#  'HIG': '502',
#  'TYL': '502',
#  'ALB': '502',
#  'HES': '502',
#  'VLO': '502',
#  'AON': '502',
#  'ANTM': '502',
#  'MCD': '502',
#  'CAT': '502',
#  'KMI': '502',
#  'BDX': '502',
#  'AMGN': '502',
#  'GLW': '502',
#  'PNR': '502',
#  'BR': '502',
#  'JKHY': '502',
#  'ETR': '502',
#  'REGN': '502',
#  'ECL': '502',
#  'AVGO': '502',
#  'CMA': '502',
#  'GOOG': '502',
#  'SNPS': '502',
#  'SIVB': '502',
#  'AMT': '502',
#  'DRE': '502',
#  'DPZ': '502',
#  'HBAN': '502',
#  'NCLH': '502',
#  'DHI': '502',
#  'MOS': '502',
#  'HSY': '502',
#  'ZION': '502',
#  'EMR': '502',
#  'LEG': '502',
#  'NEE': '502',
#  'UPS': '502',
#  'INFO': '502',
#  'WDC': '502',
#  'CB': '502',
#  'EXR': '502',
#  'PWR': '502',
#  'CCI': '502',
#  'ROST': '502',
#  'MMM': '502',
#  'TMO': '502',
#  'OXY': '502',
#  'SJM': '502',
#  'ALXN': '502',
#  'TXN': '502',
#  'QCOM': '502',
#  'TRMB': '502',
#  'TSN': '502',
#  'AKAM': '502',
#  'SYK': '502',
#  'VTRS': '502',
#  'ARE': '502',
#  'TFX': '502',
#  'TDG': '502',
#  'LLY': '502',
#  'KO': '502',
#  'TSLA': '502',
#  'IP': '502',
#  'PEP': '502',
#  'ED': '502',
#  'GL': '502',
#  'NOW': '502',
#  'PEG': '502',
#  'ES': '502',
#  'NOV': '502',
#  'GM': '502',
#  'TSCO': '502',
#  'T': '502',
#  'JBHT': '502',
#  'ESS': '502',
#  'C': '502',
#  'IRM': '502',
#  'IQV': '502',
#  'RL': '502',
#  'PPG': '502',
#  'DXC': '502',
#  'ADI': '502',
#  'HAL': '502',
#  'STZ': '502',
#  'NTRS': '502',
#  'FLS': '502',
#  'ORLY': '502',
#  'STX': '502',
#  'MPC': '502',
#  'MRK': '502',
#  'SNA': '502',
#  'TJX': '502',
#  'UNP': '502',
#  'FFIV': '502',
#  'KHC': '502',
#  'IPG': '502',
#  'CINF': '502',
#  'MKTX': '502',
#  'A': '502',
#  'V': '502',
#  'BXP': '502',
#  'NOC': '502',
#  'POOL': '502',
#  'XLNX': '502',
#  'IR': '502',
#  'NWS': '502',
#  'LOW': '502',
#  'REG': '502',
#  'PAYX': '502',
#  'ILMN': '502',
#  'PG': '502',
#  'ANET': '502',
#  'MET': '502',
#  'FTV': '502',
#  'DLR': '502',
#  'AIZ': '502',
#  'XEL': '502',
#  'FMC': '502',
#  'FBHS': '502',
#  'TWTR': '502',
#  'FLT': '502',
#  'MDT': '502',
#  'TER': '502',
#  'SO': '502',
#  'NLOK': '502',
#  'ETSY': '502',
#  'D': '502',
#  'DG': '502',
#  'HD': '502',
#  'UAL': '502',
#  'NVR': '502',
#  'FANG': '502',
#  'SBAC': '502',
#  'MRO': '502',
#  'DVN': '502',
#  'TPR': '502',
#  'NFLX': '502',
#  'ALGN': '502',
#  'FCX': '502',
#  'FITB': '502',
#  'MSI': '502',
#  'SYY': '502',
#  'ADM': '502',
#  'APH': '502',
#  'CFG': '502',
#  'HUM': '502',
#  'PSX': '502',
#  'CBRE': '502',
#  'GPN': '502',
#  'LDOS': '502',
#  'BAC': '502',
#  'LNT': '502',
#  'LNC': '502',
#  'PKI': '502',
#  'DE': '502',
#  'EA': '502',
#  'DD': '502',
#  'EW': '502',
#  'LVS': '502',
#  'WBA': '502',
#  'CMCSA': '502',
#  'F': '502',
#  'IT': '502',
#  'BBY': '502',
#  'EIX': '502',
#  'DISCK': '502',
#  'PEAK': '502',
#  'SPGI': '502',
#  'MGM': '502',
#  'HCA': '502',
#  'DTE': '502',
#  'AJG': '502',
#  'STE': '502',
#  'HAS': '502',
#  'HLT': '502',
#  'AEE': '502',
#  'APD': '502',
#  'KLAC': '502',
#  'NDAQ': '502',
#  'MKC': '502',
#  'TDY': '502',
#  'ATVI': '502',
#  'UNM': '502',
#  'KEY': '502',
#  'EVRG': '502',
#  'LMT': '502',
#  'BAX': '502',
#  'KIM': '502',
#  'WMT': '502',
#  'K': '502',
#  'GE': '502',
#  'GS': '502',
#  'EL': '502',
#  'KSU': '502',
#  'GD': '502',
#  'J': '502',
#  'AMAT': '502',
#  'WMB': '502',
#  'EQR': '502',
#  'PM': '502',
#  'GPC': '502',
#  'VRSN': '502',
#  'RE': '502',
#  'XRX': '502',
#  'TGT': '502',
#  'SLB': '502',
#  'HON': '502',
#  'ANSS': '502',
#  'MSFT': '502',
#  'AES': '502',
#  'CTAS': '502',
#  'HBI': '502',
#  'AIG': '502',
#  'DVA': '502',
#  'CTLT': '502',
#  'CRM': '502',
#  'DOV': '502',
#  'FTI': '502',
#  'CTXS': '502',
#  'CDW': '502',
#  'JNJ': '502',
#  'PPL': '502',
#  'BLK': '502',
#  'NWL': '502',
#  'UAA': '502',
#  'IEX': '502',
#  'KR': '502',
#  'BWA': '502',
#  'WAT': '502',
#  'PGR': '502',
#  'FB': '502',
#  'WAB': '502',
#  'HSIC': '502',
#  'SCHW': '502',
#  'INCY': '502',
#  'PKG': '502',
#  'EFX': '502',
#  'NUE': '502',
#  'PSA': '502',
#  'BMY': '502',
#  'RF': '502',
#  'RHI': '502',
#  'CHRW': '502',
#  'BIIB': '502',
#  'NVDA': '502',
#  'IDXX': '502',
#  'AEP': '502',
#  'TRV': '502',
#  'SWK': '502',
#  'STT': '502',
#  'ADP': '502',
#  'TEL': '502',
#  'AMZN': '502',
#  'GPS': '502',
#  'INTC': '502',
#  'RSG': '502',
#  'IFF': '502',
#  'ODFL': '502',
#  'MNST': '502',
#  'IPGP': '502',
#  'PFE': '502',
#  'LYV': '502',
#  'L': '502',
#  'INTU': '502',
#  'YUM': '502',
#  'PAYC': '502',
#  'DISCA': '502',
#  'EBAY': '502',
#  'SBUX': '502',
#  'JCI': '502',
#  'ORCL': '502',
#  'VFC': '502',
#  'DUK': '502',
#  'CSX': '502',
#  'AFL': '502',
#  'FLIR': '502',
#  'APA': '502',
#  'LUMN': '502',
#  'PYPL': '502',
#  'TFC': '502',
#  'DAL': '502',
#  'RJF': '502',
#  'ADSK': '502',
#  'PRU': '502',
#  'GOOGL': '502',
#  'UNH': '502',
#  'PCAR': '502',
#  'EXPE': '502',
#  'FTNT': '502',
#  'PFG': '502',
#  'JNPR': '502',
#  'FE': '502',
#  'LUV': '502',
#  'PHM': '502',
#  'GIS': '502',
#  'LYB': '502',
#  'O': '502',
#  'EXPD': '502',
#  'HOLX': '502',
#  'VRSK': '502',
#  'BLL': '502',
#  'PH': '502',
#  'MHK': '502',
#  'HWM': '502',
#  'DXCM': '502',
#  'SLG': '502',
#  'WELL': '502',
#  'CHD': '502',
#  'OKE': '502',
#  'SYF': '502',
#  'APTV': '502',
#  'CPB': '502',
#  'HFC': '502',
#  'SPY': '502',
#  'MTB': '502',
#  'TXT': '502',
#  'COST': '502',
#  'DHR': '502',
#  'ATO': '502',
#  'COP': '502',
#  'CNC': '502',
#  'MCK': '502',
#  'COG': '502',
#  'ROL': '502',
#  'WRB': '502',
#  'RMD': '502',
#  'CPRT': '502',
#  'NI': '502',
#  'ULTA': '502',
#  'BK': '502',
#  'ADBE': '502',
#  'MS': '502',
#  'LW': '502',
#  'HST': '502',
#  'COF': '502',
#  'JPM': '502',
#  'ABC': '502',
#  'OMC': '502',
#  'ABT': '502',
#  'AOS': '502',
#  'CVS': '502',
#  'VNO': '502',
#  'SRE': '502',
#  'VMC': '502',
#  'ALLE': '502',
#  'ABBV': '502',
#  'MMC': '502',
#  'IVZ': '502',
#  'RCL': '502',
#  'LHX': '502',
#  'PXD': '502',
#  'LB': '502',
#  'FAST': '502',
#  'CL': '502',
#  'XRAY': '502',
#  'CERN': '502',
#  'VZ': '502',
#  'UA': '502',
#  'BKNG': '502',
#  'MAA': '502',
#  'ZBRA': '502',
#  'AAL': '502',
#  'MDLZ': '502',
#  'DRI': '502',
#  'ALK': '502',
#  'MCHP': '502',
#  'CDNS': '502',
#  'MTD': '502',
#  'VAR': '502',
#  'SWKS': '502',
#  'MAR': '502',
#  'XYL': '502',
#  'CMI': '502',
#  'ENPH': '502',
#  'TAP': '502',
#  'QRVO': '502',
#  'WM': '502',
#  'EOG': '502',
#  'ITW': '502',
#  'LIN': '502',
#  'LKQ': '502',
#  'USB': '502',
#  'BSX': '502',
#  'PLD': '502',
#  'IBM': '502',
#  'NKE': '502',
#  'GILD': '502',
#  'CI': '502',
#  'NLSN': '502',
#  'EQIX': '502',
#  'MU': '502',
#  'NSC': '502',
#  'NRG': '502',
#  'ROK': '502',
#  'EMN': '502',
#  'VRTX': '502',
#  'PRGO': '502',
#  'VTR': '502',
#  'MAS': '502',
#  'CSCO': '502',
#  'TROW': '502',
#  'ISRG': '502',
#  'FIS': '502',
#  'ALL': '502',
#  'HII': '502',
#  'AVB': '502',
#  'DIS': '502',
#  'DGX': '502',
#  'LEN': '502',
#  'GWW': '502',
#  'WY': '502',
#  'WST': '502',
#  'CBOE': '502',
#  'ETN': '502',
#  'DISH': '502',
#  'WFC': '502',
#  'MA': '502',
#  'NEM': '502',
#  'KMB': '502',
#  'PVH': '502',
#  'TT': '502',
#  'CAH': '502',
#  'CNP': '502',
#  'CLX': '502',
#  'MCO': '502',
#  'WLTW': '502',
#  'MSCI': '502',
#  'CHTR': '502'}
